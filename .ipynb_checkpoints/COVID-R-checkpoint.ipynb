# %%
import requests,json
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

url = 'https://covidapi.info/api/v1/country/GBR'
response = requests.get(url)
if response.status_code==200:
    data= json.loads(response.content)['result']
    days=[{**data[d],'date':d} for d in data]#[:-5] # Merging two dicts
    active=[day['confirmed']-day['recovered']-day['deaths'] for day in days]
    plt.plot([day['confirmed'] for day in days])
else:
    print('Data for country code not found')

# %%
newTrueCases=[0 for x in active]
newReportedCases=[0 for x in active]
mu, sigma = -10, 3
cutoff=15
for i in range(len(days)):
    if i>0:
        newReportedCases[i]=days[i]['confirmed']-days[i-1]['confirmed']
        dist = np.around(np.random.normal(mu, sigma, abs(newReportedCases[i])))# taking abs for taking of weird data that number of confirmed cases decreased
        dayOffsets, counts = np.unique(dist, return_counts=True)
        for j in range(len(dayOffsets)):
            dayOffset=dayOffsets[j]
            day=int(i+dayOffset)
            if(day>0 and day<(len(active)-cutoff)):
                if(newReportedCases[i]>0):
                    newTrueCases[day]+=counts[j]
                else:
                    newTrueCases[day]-=counts[j]# again for those negative values that come in some data.

newTrueCases=newTrueCases[:-cutoff]

i = 0
moving_averages = []
window_size=5
while i < len(newTrueCases) - window_size + 1:
    this_window = newTrueCases[i : i + window_size]
    window_average = sum(this_window) / window_size
    moving_averages.append(window_average)
    i += 1

newTrueCases=moving_averages

r=[0 for x in newTrueCases]
for i in range(1,len(newTrueCases)):
    if(newTrueCases[i-1]>0):
        r[i]=newTrueCases[i]/newTrueCases[i-1]
        print("{} : {}".format(days[i+window_size]['date'],r[i]))
    
plt.plot(newTrueCases)
#plt.plot(active)
plt.plot(newReportedCases)
#plt.plot(r)
# Out:
# 2020-01-28 : 1.0
# 2020-01-29 : 1.0
# 2020-01-30 : 0.0
# 2020-02-02 : 4.0
# 2020-02-03 : 1.25
# 2020-02-04 : 1.0
# 2020-02-05 : 1.2
# 2020-02-06 : 0.8333333333333334
# 2020-02-07 : 0.4
# 2020-02-08 : 0.5
# 2020-02-09 : 1.0
# 2020-02-10 : 0.0
# 2020-02-13 : 1.0
# 2020-02-14 : 1.0
# 2020-02-15 : 2.5
# 2020-02-16 : 1.0
# 2020-02-17 : 1.2
# 2020-02-18 : 1.5
# 2020-02-19 : 2.0
# 2020-02-20 : 1.6666666666666665
# 2020-02-21 : 1.2333333333333334
# 2020-02-22 : 1.3243243243243243
# 2020-02-23 : 1.3673469387755102
# 2020-02-24 : 1.4029850746268657
# 2020-02-25 : 1.2446808510638296
# 2020-02-26 : 1.3162393162393164
# 2020-02-27 : 1.2662337662337662
# 2020-02-28 : 1.158974358974359
# 2020-02-29 : 1.2123893805309733
# 2020-03-01 : 1.2956204379562044
# 2020-03-02 : 1.1577464788732394
# 2020-03-03 : 1.2481751824817517
# 2020-03-04 : 1.3060428849902534
# 2020-03-05 : 1.2776119402985073
# 2020-03-06 : 1.1670560747663552
# 2020-03-07 : 1.303303303303303
# 2020-03-08 : 1.2488479262672811
# 2020-03-09 : 1.2429274292742927
# 2020-03-10 : 1.1771400296882732
# 2020-03-11 : 1.2328709541824296
# 2020-03-12 : 1.1974087964541424
# 2020-03-13 : 1.1810933940774488
# 2020-03-14 : 1.1697203471552555
# 2020-03-15 : 1.1846661170651278
# 2020-03-16 : 1.165970772442589
# 2020-03-17 : 1.1606982990152193
# 2020-03-18 : 1.151947551099113
# 2020-03-19 : 1.1475281776587434
# 2020-03-20 : 1.1281727122435086
# 2020-03-21 : 1.1099905180587881
# 2020-03-22 : 1.0969169837695114
# 2020-03-23 : 1.0948672566371682
# 2020-03-24 : 1.0880698351115423
# 2020-03-25 : 1.077435074582516
# 2020-03-26 : 1.0699393270821842
# 2020-03-27 : 1.0749046293432312
# 2020-03-28 : 1.0537624094767637
# 2020-03-29 : 1.0458310577098127
# 2020-03-30 : 1.0371643674659472
# 2020-03-31 : 1.03818235220073
# 2020-04-01 : 1.0224305864284848
# 2020-04-02 : 1.0262866629773104
# 2020-04-03 : 1.012094133959866
# 2020-04-04 : 1.0078776115994978
# 2020-04-05 : 0.9968660323214016
# 2020-04-06 : 0.9923108973144957
# 2020-04-07 : 0.9922513168944194
# 2020-04-08 : 0.9880746297364877
# 2020-04-09 : 0.9993381350983065
# 2020-04-10 : 0.9959482624279258
# 2020-04-11 : 0.991472383038648
# 2020-04-12 : 0.9853625818669612
# 2020-04-13 : 0.9911911911911911
# 2020-04-14 : 0.9864673803272066
# 2020-04-15 : 0.9872645372645373
# 2020-04-16 : 0.9913725164876187
# 2020-04-17 : 0.9893728295887201
# 2020-04-18 : 0.990950226244344
